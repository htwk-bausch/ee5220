# %% [markdown]
# # Demo: Faltung

# %%
import numpy as np
import matplotlib.pyplot as plt

import librosa.display
from IPython.display import Audio

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Gunshot-Sound

# %%
gunshot, gunshot_fs = librosa.load('../data/gunshot.wav')

# Anzeige Abtastrate und Anzahl der Samples
print("Abtastrate (Hz): %d" % gunshot_fs)
print("Anzahl Samples: %d" % gunshot.shape[0])
# Out:
# Abtastrate (Hz): 22050
# Anzahl Samples: 38293

# %%
t = np.arange(0, gunshot.shape[0]/gunshot_fs, 1/gunshot_fs);

plt.figure(figsize=(14,5))
plt.plot(t, gunshot)
plt.xlabel('Zeit [Sek.]');
plt.ylabel('Amplitude (norm.)');
plt.grid(True);

Audio(gunshot, rate=gunshot_fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Violine

# %%
violin, violin_fs = librosa.load('../data/violin.wav')

print("Abtastrate (Hz): %d" % violin_fs)
print("Anzahl Samples: %d" % violin.shape[0])
# Out:
# Abtastrate (Hz): 22050
# Anzahl Samples: 110250

# %%
t = np.arange(0, violin.shape[0]/violin_fs, 1/violin_fs);

plt.figure(figsize=(14,5))
plt.plot(t, violin)
plt.xlabel('Zeit [Sek.]');
plt.ylabel('Amplitude (norm.)');
plt.grid(True);

Audio(violin, rate=violin_fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Faltung des Violinen-Sounds mit Gunshot

# %%
violin_gunshot = np.convolve(violin, gunshot)

t = np.arange(0, violin_gunshot.shape[0]/violin_fs, 1/violin_fs);

plt.figure(figsize=(14,5))
plt.plot(t, violin_gunshot)
plt.xlabel('Zeit [Sek.]');
plt.ylabel('Amplitude (norm.)');
plt.grid(True);

Audio(violin_gunshot, rate=violin_fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Faltung mit alternativem Sound

# %%
sound, sound_fs = librosa.load('../data/HumanVoice_TestHelloCount1_16bit_44.1kHz_mono.wav')
# Out:
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1182             raise TypeError("Invalid file: {0!r}".format(self.name))
# -> 1183         _error_check(_snd.sf_error(file_ptr),
#    1184                      "Error opening {0!r}: ".format(self.name))
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/soundfile.py in _error_check(err, prefix)
#    1356         err_str = _snd.sf_error_number(err)
# -> 1357         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1358
#
# RuntimeError: Error opening '../data/HumanVoice_TestHelloCount1_16bit_44.1kHz_mono.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5718/267834444.py in <module>
# ----> 1 sound, sound_fs = librosa.load('../data/HumanVoice_TestHelloCount1_16bit_44.1kHz_mono.wav')
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     164         if isinstance(path, (str, pathlib.PurePath)):
#     165             warnings.warn("PySoundFile failed. Trying audioread instead.")
# --> 166             y, sr_native = __audioread_load(path, offset, duration, dtype)
#     167         else:
#     168             raise (exc)
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     188
#     189     y = []
# --> 190     with audioread.audio_open(path) as input_file:
#     191         sr_native = input_file.samplerate
#     192         n_channels = input_file.channels
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/audioread/__init__.py in audio_open(path, backends)
#     109     for BackendClass in backends:
#     110         try:
# --> 111             return BackendClass(path)
#     112         except DecodeError:
#     113             pass
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/audioread/rawread.py in __init__(self, filename)
#      60     """
#      61     def __init__(self, filename):
# ---> 62         self._fh = open(filename, 'rb')
#      63
#      64         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/HumanVoice_TestHelloCount1_16bit_44.1kHz_mono.wav'
